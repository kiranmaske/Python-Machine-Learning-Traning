# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df=pd.read_csv('Instagram visits clustering.csv')
print("the shape of data is",df.shape)
df.head()
# Out:
# the shape of data is (2600, 3)
#    User ID  Instagram visit score  Spending_rank(0 to 100)
# 0        0                     63                24.050708
# 1        1                     61                25.223290
# 2        2                    104                18.528245
# 3        3                     82                86.890232
# 4        4                     14                31.492397

# %%
plt.scatter(df['Instagram visit score'],df['Spending_rank(0 to 100)'])

# %%
from sklearn.cluster import KMeans

# %%
wcss=[]
for i  in range(1,11):
    km = KMeans(n_clusters=i)
# n_clusters defult values is 8 here we use for loop with range (1,11)
    km.fit_predict(df)
    wcss.append(km.inertia_)

# %%
wcss
# Out:
# [1468652084.7796714,
#  370162274.51862705,
#  166756383.57992932,
#  95529769.70751807,
#  62645646.95492384,
#  44710063.59488183,
#  33948429.200336166,
#  26946764.23470238,
#  22239136.949395057,
#  18701546.367806207]

# %%
plt.plot(range(1,11),wcss)

# %%
x=df.iloc[:,:].values
km=KMeans(n_clusters=i)
y_means = km.fit_predict(x)

# %%
y_means
# Out:
# array([7, 7, 7, ..., 6, 6, 6])

# %%
x[y_means == 3,1]
# Out:
# array([ 77.,  32.,  87.,  54., 101.,  78.,  32.,  29.,  80.,  24.,  74.,
#         69.,  63.,  91.,  21.,  31.,  54.,  84.,  45.,  86.,  94.,  83.,
#         60.,  40.,  24.,  57.,  45.,  88.,  21.,  74.,  82.,  85.,  88.,
#         89.,  91.,  78.,  17.,  88.,  26.,  83.,  78.,  84.,  35.,  86.,
#         99.,  72.,  91.,  16.,  87.,  73.,  51.,  87.,  89.,  49.,  90.,
#         97.,  27.,  46.,  77., 100.,  80.,  16.,  42.,  83.,   5.,  86.,
#         84.,  29.,  19.,  30.,  85.,  93.,  84.,  56.,  18.,  19.,  88.,
#         46.,  34.,  98.,  20.,  84.,  76.,  17.,  92.,  80.,  74.,  33.,
#         71.,  90.,  80.,  77.,  33.,  27.,  92.,  79.,  96.,  44.,  81.,
#         34.,  71., 109.,  59.,  21.,  43.,  87.,  49.,  30.,  22.,  73.,
#         28.,  82.,  81.,  88.,  88.,  96.,  93.,  69.,  41.,  87.,  80.,
#         48.,  78.,  21.,  41.,  77.,  17.,  42.,  83.,  86.,  36.,  81.,
#         90.,  31.,  37.,  68.,  78.,  98.,  66.,  78.,  87.,  93.,  95.,
# ...

# %%
plt.scatter(x[y_means ==0,0],x[y_means==0,1],color='blue')
plt.scatter(x[y_means ==1,0],x[y_means==1,1],color='red')
plt.scatter(x[y_means ==2,0],x[y_means==2,1],color='green')
plt.scatter(x[y_means ==3,0],x[y_means==3,1],color='yellow')
plt.scatter(x[y_means ==4,0],x[y_means==4,1],color='pink')
