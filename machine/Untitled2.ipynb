# %%
courses = ['python', 'ML', 'java', 'R']

if 'ML' in courses:
    print("ML")
else:
    print("Not Found")
# Out:
# ML

# %%
a=10;
b=0;

try:
    print("Addition is :",a+b)
    print("Division is :",a/b)
except ZeroDivisionError:
    print(" Division by zero is not allowed.")
    print("substraction is :",a-b)
    print("multipllication is :",a*b)
# Out:
# Addition is : 10
#  Division by zero is not allowed.
# substraction is : 10
# multipllication is : 0
