# %%
import numpy as np
import pandas as pd
import seaborn as sns 
import matplotlib.pyplot as plt

# %%
pd.read_csv('placement.csv')
# Out:
#      cgpa  placement_exam_marks  placed
# 0    7.19                  26.0       1
# 1    7.46                  38.0       1
# 2    7.54                  40.0       1
# 3    6.42                   8.0       1
# 4    7.23                  17.0       0
# ..    ...                   ...     ...
# 995  8.87                  44.0       1
# 996  9.12                  65.0       1
# 997  4.89                  34.0       0
# 998  8.62                  46.0       1
# 999  4.90                  10.0       1
#
# [1000 rows x 3 columns]

# %%
df=pd.read_csv('placement.csv')

# %%
df.head()
# Out:
#    cgpa  placement_exam_marks  placed
# 0  7.19                  26.0       1
# 1  7.46                  38.0       1
# 2  7.54                  40.0       1
# 3  6.42                   8.0       1
# 4  7.23                  17.0       0

# %%
plt.figure(figsize=(16,5))
plt.subplot(1,2,1)
sns.displot(df['cgpa'])

plt.subplot(1,2,2)
sns.displot(df['placement_exam_marks'])
plt.show()

# %%
df['placement_exam_marks'].describe()
# Out:
# count    1000.000000
# mean       32.225000
# std        19.130822
# min         0.000000
# 25%        17.000000
# 50%        28.000000
# 75%        44.000000
# max       100.000000
# Name: placement_exam_marks, dtype: float64

# %%
sns.boxplot(df['placement_exam_marks'],
            orient='h',color='yellow')
# Out:
# <Axes: xlabel='placement_exam_marks'>

# %%
Q1 = df['placement_exam_marks'].quantile(0.25)
Q3= df['placement_exam_marks'].quantile(0.75)
print("value of Q1",Q1)
# Out:
# value of Q1 17.0

# %%
print("values of Q3",Q3)
# Out:
# values of Q3 44.0

# %%
# formula IQR=Q3-Q1 
iqr=Q3-Q1

# %%
iqr
# Out:
# 27.0

# %%
upper_limit=Q3+1.5*iqr
lower_limit=Q1-1.5*iqr

# %%
print("Upper_limit",upper_limit)
print("Lower_limit",lower_limit)
# Out:
# Upper_limit 84.5
# Lower_limit -23.5

# %%
# Finding outlier 

df[df['placement_exam_marks']>upper_limit]
# Out:
#      cgpa  placement_exam_marks  placed
# 9    7.75                  94.0       1
# 40   6.60                  86.0       1
# 61   7.51                  86.0       0
# 134  6.33                  93.0       0
# 162  7.80                  90.0       0
# 283  7.09                  87.0       0
# 290  8.38                  87.0       0
# 311  6.97                  87.0       1
# 324  6.64                  90.0       0
# 630  6.56                  96.0       1
# 685  6.05                  87.0       1
# 730  6.14                  90.0       1
# 771  7.31                  86.0       1
# 846  6.99                  97.0       0
# 917  5.95                 100.0       0

# %%
df[df['placement_exam_marks']<lower_limit]
# Out:
# Empty DataFrame
# Columns: [cgpa, placement_exam_marks, placed]
# Index: []

# %%
df1=df[df['placement_exam_marks']>upper_limit]

# %%
df1.shape
# Out:
# (15, 3)

# %%
new_df =df[df['placement_exam_marks']>upper_limit]

# %%
new_df
# Out:
#      cgpa  placement_exam_marks  placed
# 9    7.75                  94.0       1
# 40   6.60                  86.0       1
# 61   7.51                  86.0       0
# 134  6.33                  93.0       0
# 162  7.80                  90.0       0
# 283  7.09                  87.0       0
# 290  8.38                  87.0       0
# 311  6.97                  87.0       1
# 324  6.64                  90.0       0
# 630  6.56                  96.0       1
# 685  6.05                  87.0       1
# 730  6.14                  90.0       1
# 771  7.31                  86.0       1
# 846  6.99                  97.0       0
# 917  5.95                 100.0       0

# %%
new_df.shape
# Out:
# (15, 3)

# %%
plt.figure(figsize=(16,5))
plt.subplot(2,2,1)
sns.displot(df['placement_exam_marks'],color='green')

plt.subplot(2,2,2)
sns.boxplot(df['placement_exam_marks'],orient='h',color='blue')

plt.subplot(2,2,3)
sns.displot(new_df['placement_exam_marks'],color='red')
plt.show()

plt.subplot(2,2,4)
sns.boxplot(new_df['placement_exam_marks'],orient='h',color='green')
plt.show()
