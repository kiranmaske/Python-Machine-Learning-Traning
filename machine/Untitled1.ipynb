# %%
import numpy as np
import pandas as pd
import seaborn as sns 
import matplotlib.pyplot as plt

# %%
pd.read_csv('Result_Student.csv')
# Out:
#    Student ID  Class  Study hrs  Social Media usage hrs  Percentage  Grade  \
# 0        1001     10          2                       3          50    Avg
# 1        1002     10          6                       2          80  Vgood
# 2        1003     10          3                       2          60   Good
# 3        1004     11          0                       1          45   Fail
# 4        1005     12          5                       2          75   Good
#
#    Gender
# 0  Female
# 1    Male
# 2  Female
# 3    Male
# 4  Female

# %%
df=pd.read_csv('Result_Student.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 7 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Student ID              5 non-null      int64
#  1   Class                   5 non-null      int64
#  2   Study hrs               5 non-null      int64
#  3   Social Media usage hrs  5 non-null      int64
#  4   Percentage              5 non-null      int64
#  5   Grade                   5 non-null      object
#  6   Gender                  5 non-null      object
# dtypes: int64(5), object(2)
# memory usage: 408.0+ bytes

# %%
df1=df.iloc[:,5:6]
df1.head()
# Out:
#    Grade
# 0    Avg
# 1  Vgood
# 2   Good
# 3   Fail
# 4   Good

# %%
df1['Grade'].value_counts()
# Out:
# Grade
# Good     2
# Avg      1
# Vgood    1
# Fail     1
# Name: count, dtype: int64

# %%
df1['Gender'].value_counts()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\indexes\base.py:3812, in Index.get_loc(self, key)
#    3811 try:
# -> 3812     return self._engine.get_loc(casted_key)
#    3813 except KeyError as err:
#
# File pandas/_libs/index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7096, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Gender'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[46], line 1
# ...

# %%
from sklearn.preprocessing import OrdinalEncoder
oe=OrdinalEncoder(categories=[['Avg','Vgood','Good','Fail']])

df1_oe= oe.fit_transform(df1)
df1_oe
# Out:
# array([[0.],
#        [1.],
#        [2.],
#        [3.],
#        [2.]])

# %%
import numpy as np
type(df1_oe)
np.ndarray
df1=pd.DataFrame(df1_oe,columns=['Grade'])
df1.head()
# Out:
#    Grade
# 0    0.0
# 1    1.0
# 2    2.0
# 3    3.0
# 4    2.0

# %%
df.update(df1)
df.head()
# Out:
#    Student ID  Class  Study hrs  Social Media usage hrs  Percentage Grade  \
# 0        1001     10          2                       3          50   0.0
# 1        1002     10          6                       2          80   1.0
# 2        1003     10          3                       2          60   2.0
# 3        1004     11          0                       1          45   3.0
# 4        1005     12          5                       2          75   2.0
#
#   Gender
# 0    0.0
# 1    1.0
# 2    0.0
# 3    1.0
# 4    0.0

# %%
df['Grade']=df["Grade"].astype(int)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 7 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Student ID              5 non-null      int64
#  1   Class                   5 non-null      int64
#  2   Study hrs               5 non-null      int64
#  3   Social Media usage hrs  5 non-null      int64
#  4   Percentage              5 non-null      int64
#  5   Grade                   5 non-null      int32
#  6   Gender                  5 non-null      object
# dtypes: int32(1), int64(5), object(1)
# memory usage: 388.0+ bytes

# %%
#lable encoder 
df2=df[['Grade','Gender']]
df2.head()
# Out:
#    Grade Gender
# 0      0    0.0
# 1      1    1.0
# 2      2    0.0
# 3      3    1.0
# 4      2    0.0

# %%
df.update(df2)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 7 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Student ID              5 non-null      int64
#  1   Class                   5 non-null      int64
#  2   Study hrs               5 non-null      int64
#  3   Social Media usage hrs  5 non-null      int64
#  4   Percentage              5 non-null      int64
#  5   Grade                   5 non-null      int32
#  6   Gender                  5 non-null      object
# dtypes: int32(1), int64(5), object(1)
# memory usage: 388.0+ bytes

# %%
df.to_csv('_encoder.csv')  # dowload file 
import os  #see location 
os.getcwd()
