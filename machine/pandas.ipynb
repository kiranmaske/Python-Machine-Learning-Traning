# %%
import pandas as pd

# %%
l1 = [1,2,-3,4.5,'indian']
print(l1)
# Out:
# [1, 2, -3, 4.5, 'indian']

# %%
import pandas as pd

s1 = pd.Series(l1)
print(s1)
# Out:
# 0         1
# 1         2
# 2        -3
# 3       4.5
# 4    indian
# dtype: object

# %%
s2= pd.Series([1,2,3,4,5])
print(s2)
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# 4    5
# dtype: int64

# %%
series2= pd.Series([1,2,3,4,5],
                   index = ['a', 'b','c','d','e'])
print(series2)
# Out:
# a    1
# b    2
# c    3
# d    4
# e    5
# dtype: int64

# %%
series2= pd.Series([1,2,3,4,5],
                   index = ['a', 'b','c','d','e'],
                   dtype= float)
print(series2)
# Out:
# a    1.0
# b    2.0
# c    3.0
# d    4.0
# e    5.0
# dtype: float64

# %%
#slicing series

# %%
s5= pd.Series([1,2,3,4,5])
s6= pd.Series([1,2,3,4,5])
a=s5+s6                   
print(a)
# Out:
# 0     2
# 1     4
# 2     6
# 3     8
# 4    10
# dtype: int64

# %%
# we can also add seris add method 
s5.add(s6)
# Out:
# 0     2
# 1     4
# 2     6
# 3     8
# 4    10
# dtype: int64
