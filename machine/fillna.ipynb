# %%
import numpy as np
import pandas as pd
import seaborn as sns 
import matplotlib.pyplot as plt

# %%
pd.read_csv('SIT.csv')
# Out:
#       User ID  Gender   Age  EstimatedSalary  Purchased
# 0    15624510    Male  19.0          19000.0        0.0
# 1    15810944    Male  35.0          20000.0        0.0
# 2    15668575  Female  26.0          43000.0        0.0
# 3    15603246  Female  27.0          57000.0        0.0
# 4    15804002    Male  19.0          76000.0        0.0
# ..        ...     ...   ...              ...        ...
# 395  15691863  Female  46.0          41000.0        1.0
# 396  15706071    Male  51.0          23000.0        1.0
# 397  15654296  Female  50.0          20000.0        1.0
# 398  15755018    Male  36.0          33000.0        0.0
# 399  15594041  Female  49.0          36000.0        1.0
#
# [400 rows x 5 columns]

# %%
df=pd.read_csv('SIT.csv')

# %%
df.shape
# Out:
# (400, 5)

# %%
df.size
# Out:
# 2000

# %%
df.describe()
# Out:
#             User ID         Age  EstimatedSalary   Purchased
# count  4.000000e+02  365.000000       369.000000  369.000000
# mean   1.569154e+07   38.405479     71368.563686    0.357724
# std    7.165832e+04   10.489659     33959.929846    0.479981
# min    1.556669e+07   18.000000     15000.000000    0.000000
# 25%    1.562676e+07   31.000000     46000.000000    0.000000
# 50%    1.569434e+07   38.000000     71000.000000    0.000000
# 75%    1.575036e+07   46.000000     88000.000000    1.000000
# max    1.581524e+07   60.000000    150000.000000    1.000000

# %%
 df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 400 entries, 0 to 399
# Data columns (total 5 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   User ID          400 non-null    int64
#  1   Gender           371 non-null    object
#  2   Age              365 non-null    float64
#  3   EstimatedSalary  369 non-null    float64
#  4   Purchased        369 non-null    float64
# dtypes: float64(3), int64(1), object(1)
# memory usage: 15.8+ KB

# %%
df.isnull().sum()
# Out:
# User ID             0
# Gender             29
# Age                35
# EstimatedSalary    31
# Purchased          31
# dtype: int64

# %%
df = df.select_dtypes(include=['int64', 'float64'])
df.head()
# Out:
#     User ID   Age  EstimatedSalary  Purchased
# 0  15624510  19.0          19000.0        0.0
# 1  15810944  35.0          20000.0        0.0
# 2  15668575  26.0          43000.0        0.0
# 3  15603246  27.0          57000.0        0.0
# 4  15804002  19.0          76000.0        0.0

# %%
plt.figure(figsize=(16,10))
sns.heatmap(df.isnull())
# Out:
# <Axes: >

# %%
# ploting age coloumn to check distribution

# %%
sns.distplot(df['Age'])
# Out:
# C:\Users\Kiran Maske\AppData\Local\Temp\ipykernel_26768\3255828239.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['Age'])
# <Axes: xlabel='Age', ylabel='Density'>

# %%
sns.distplot(df['EstimatedSalary'])
# Out:
# C:\Users\Kiran Maske\AppData\Local\Temp\ipykernel_26768\2218174724.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['EstimatedSalary'])
# <Axes: xlabel='EstimatedSalary', ylabel='Density'>

# %%
sns.distplot(df['Purchased'])
# Out:
# C:\Users\Kiran Maske\AppData\Local\Temp\ipykernel_26768\3541655672.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['Purchased'])
# <Axes: xlabel='Purchased', ylabel='Density'>

# %%
df_mean = df.fillna(df.mean())
#fillna() is used to fill missing value 
#now it fill it using mean

# %%
print(type(df.mean))
# Out:
# <class 'method'>

# %%
df_mean = df.fillna(df.mean())

# %%
mean = df

# %%
cat_vars = df.select_dtypes(include=['object'])

# %%
cat_vars.isnull().sum()
# Out:
# Series([], dtype: float64)

# %%
cat_vars=pd.read_csv('SIT.csv')
cat_vars['Gender'].value_counts()
# Out:
# Gender
# Female    191
# Male      180
# Name: count, dtype: int64

# %%
cat_vars['Gender'].fillna('Female',inplace=True)
# Out:
# C:\Users\Kiran Maske\AppData\Local\Temp\ipykernel_26768\2075415895.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   cat_vars['Gender'].fillna('Female',inplace=True)

# %%
cat_vars.isnull().sum().sum()
# Out:
# 97

# %%
cat_vars = df.fillna(df.mean())

# %%
cat_vars.isnull().sum().sum()
# Out:
# 0

# %%
df.update(cat_vars)

# %%
df.update(df_mean)

# %%
df.isnull().sum()
# Out:
# User ID            0
# Age                0
# EstimatedSalary    0
# Purchased          0
# dtype: int64

# %%
df
# Out:
#       User ID   Age  EstimatedSalary  Purchased
# 0    15624510  19.0          19000.0        0.0
# 1    15810944  35.0          20000.0        0.0
# 2    15668575  26.0          43000.0        0.0
# 3    15603246  27.0          57000.0        0.0
# 4    15804002  19.0          76000.0        0.0
# ..        ...   ...              ...        ...
# 395  15691863  46.0          41000.0        1.0
# 396  15706071  51.0          23000.0        1.0
# 397  15654296  50.0          20000.0        1.0
# 398  15755018  36.0          33000.0        0.0
# 399  15594041  49.0          36000.0        1.0
#
# [400 rows x 4 columns]
