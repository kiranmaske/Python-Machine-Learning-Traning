# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df=pd.read_csv('student_clustering.csv')
print("the shape of data is",df.shape)
df.head()
# Out:
# the shape of data is (200, 2)
#    cgpa   iq
# 0  5.13   88
# 1  5.90  113
# 2  8.36   93
# 3  8.27   97
# 4  5.45  110

# %%
plt.scatter(df['cgpa'],df['iq'])

# %%
from sklearn.cluster import KMeans

# %%
wcss=[]
for i  in range(1,11):
    km = KMeans(n_clusters=i)
# n_clusters defult values is 8 here we use for loop with range (1,11)
    km.fit_predict(df)
    wcss.append(km.inertia_)

# %%
wcss
# Out:
# [29957.898287999997,
#  4184.14127,
#  2364.0055834200834,
#  681.96966,
#  523.7131894763966,
#  444.9002306809091,
#  344.1682679067785,
#  234.48687343199217,
#  239.79077319394426,
#  197.32098460785593]

# %%
plt.plot(range(1,11),wcss)

# %%
x=df.iloc[:,:].values
km=KMeans(n_clusters=i)
y_means = km.fit_predict(x)

# %%
y_means
# Out:
# array([0, 1, 2, 5, 1, 6, 5, 3, 1, 2, 0, 1, 5, 0, 6, 2, 1, 7, 1, 1, 5, 0,
#        7, 0, 0, 5, 0, 9, 2, 4, 3, 1, 9, 4, 5, 5, 9, 6, 8, 1, 8, 5, 2, 0,
#        3, 3, 2, 6, 9, 6, 8, 0, 3, 5, 3, 6, 1, 3, 6, 3, 4, 5, 2, 9, 0, 1,
#        2, 8, 1, 2, 6, 3, 2, 8, 6, 9, 1, 3, 0, 7, 7, 9, 1, 8, 3, 0, 3, 6,
#        3, 6, 3, 3, 7, 0, 2, 2, 9, 2, 7, 9, 1, 0, 0, 9, 0, 0, 7, 0, 9, 9,
#        2, 3, 6, 1, 7, 9, 2, 6, 3, 0, 0, 6, 2, 9, 5, 8, 5, 6, 0, 5, 2, 1,
#        8, 0, 1, 9, 6, 0, 5, 5, 2, 8, 1, 0, 0, 9, 0, 3, 6, 0, 3, 8, 3, 3,
#        0, 2, 1, 9, 1, 2, 0, 9, 6, 7, 3, 0, 6, 8, 0, 9, 9, 1, 3, 0, 0, 5,
#        3, 6, 0, 3, 3, 6, 1, 6, 5, 0, 2, 7, 3, 1, 2, 2, 0, 8, 5, 0, 9, 1,
#        6, 3])

# %%
x[y_means == 3,1]
# Out:
# array([115., 117., 116., 116., 116., 115., 115., 117., 116., 117., 116.,
#        117., 117., 117., 114., 117., 117., 117., 117., 117., 116., 117.,
#        117., 115., 115., 117., 116., 117.])

# %%
plt.scatter(x[y_means ==0,0],x[y_means==0,1],color='blue')
plt.scatter(x[y_means ==1,0],x[y_means==1,1],color='red')
plt.scatter(x[y_means ==2,0],x[y_means==2,1],color='green')
plt.scatter(x[y_means ==3,0],x[y_means==3,1],color='yellow')
plt.figure(facecolor='lightblue')
